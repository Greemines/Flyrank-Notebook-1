# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Greemines/Flyrank-Notebook-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am going to choose the CTR/ Engagement opportunity scoring lane because improving the click-through rate and user engangment can increase the value of the existing content without having the need to create a new page. Many pages receive impressions in searches but still fail to attract clicks or keep the users engaged. Identifying these pages can help the project prioritize which content should be reviewed first to imporove titles, description or on page content.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# This project will help content managers decide which pages should be prioritized for CTR and engagement. They can review page titles, descriptions and content quality and user experience based on the ranked recommendations and encourage more clicks and better egagement. A wrong recommendation can cause the team to waste their time on pages that have little oppurtunity for improvement while overlooking pages with genuine opimization potential. This can reduce the effectiveness of limited time and resources and delay improvements that can help increase website traffic and user engagement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content_refresh_anonymized.csv")

print("Total pages:", len(df))

print("Average CTR:", df["ctr"].mean())

print("Average impressions:", df["impressions_90d"].mean())

print("Pages with >500 impressions:",
      (df["impressions_90d"] > 500).sum())

print("Pages with CTR below 0.5:",
      (df["ctr"] < 0.5).sum())
# Out:
# Total pages: 30000
# Average CTR: 0.5107333333333334
# Average impressions: 5200.3663
# Pages with >500 impressions: 16715
# Pages with CTR below 0.5: 25750

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# The aim of this project is to indentify pages that appear for improving CTR and engagement based on observed performance metrics. The results are supposed to help human descision making rather than replacing it. This project cannot prove that improving a page will increase its traffic nor can it predict Google's ranking algorithm. It only identifies patterns within the available data that can help prioritize content reviews

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
